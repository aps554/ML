# %%
import numpy as np
import pandas as pd
iris =   pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")

# %%
iris.head()
df=iris.copy()
df.tail()
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
df.iloc[0:3,1:3]
# Out:
#    3.5  1.4
# 0  3.0  1.4
# 1  3.2  1.3
# 2  3.1  1.5

# %%
df.columns=["pl","pw","sl","sw","FlowerType"]
df.head()
df.describe()
# Out:
#                pl          pw          sl          sw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.columns
# Out:
# Index(['pl', 'pw', 'sl', 'sw', 'FlowerType'], dtype='object')

# %%
df.drop(0,inplace=True)
df.drop(12,inplace=True)
df.drop(3,inplace=True)

# %%
for i in range(5):
    df.drop(i,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-81d1752dbd47> in <module>()
#       1 for i in range(5):
# ----> 2     df.drop(i,inplace=True)
#       3
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
df=iris.copy()
df.columns=["pl","pw","sl","sw","FlowerType"]
df.head()
# Out:
#     pl   pw   sl   sw   FlowerType
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.describe()
# Out:
#                pl          pw          sl          sw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.iloc[:,1:4]
# Out:
#       pw   sl   sw
# 0    3.0  1.4  0.2
# 1    3.2  1.3  0.2
# 2    3.1  1.5  0.2
# 3    3.6  1.4  0.2
# 4    3.9  1.7  0.4
# 5    3.4  1.4  0.3
# 6    3.4  1.5  0.2
# 7    2.9  1.4  0.2
# 8    3.1  1.5  0.1
# 9    3.7  1.5  0.2
# 10   3.4  1.6  0.2
# 11   3.0  1.4  0.1
# 12   3.0  1.1  0.1
# 13   4.0  1.2  0.2
# 14   4.4  1.5  0.4
# 15   3.9  1.3  0.4
# 16   3.5  1.4  0.3
# 17   3.8  1.7  0.3
# 18   3.8  1.5  0.3
# 19   3.4  1.7  0.2
# 20   3.7  1.5  0.4
# 21   3.6  1.0  0.2
# 22   3.3  1.7  0.5
# 23   3.4  1.9  0.2
# 24   3.0  1.6  0.2
# 25   3.4  1.6  0.4
# 26   3.5  1.5  0.2
# 27   3.4  1.4  0.2
# 28   3.2  1.6  0.2
# 29   3.1  1.6  0.2
# ..   ...  ...  ...
# 119  3.2  5.7  2.3
# 120  2.8  4.9  2.0
# 121  2.8  6.7  2.0
# 122  2.7  4.9  1.8
# 123  3.3  5.7  2.1
# 124  3.2  6.0  1.8
# 125  2.8  4.8  1.8
# 126  3.0  4.9  1.8
# 127  2.8  5.6  2.1
# 128  3.0  5.8  1.6
# 129  2.8  6.1  1.9
# 130  3.8  6.4  2.0
# 131  2.8  5.6  2.2
# 132  2.8  5.1  1.5
# 133  2.6  5.6  1.4
# ...

# %%
df.isnull().sum()
# Out:
# pl            0
# pw            0
# sl            0
# sw            0
# FlowerType    0
# dtype: int64

# %%
df.pl
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
# 5      4.6
# 6      5.0
# 7      4.4
# 8      4.9
# 9      5.4
# 10     4.8
# 11     4.8
# 12     4.3
# 13     5.8
# 14     5.7
# 15     5.4
# 16     5.1
# 17     5.7
# 18     5.1
# 19     5.4
# 20     5.1
# 21     4.6
# 22     5.1
# 23     4.8
# 24     5.0
# 25     5.0
# 26     5.2
# 27     5.2
# 28     4.7
# 29     4.8
#       ...
# 119    6.9
# 120    5.6
# 121    7.7
# 122    6.3
# 123    6.7
# 124    7.2
# 125    6.2
# 126    6.1
# 127    6.4
# 128    7.2
# 129    7.4
# 130    7.9
# 131    6.4
# 132    6.3
# 133    6.1
# 134    7.7
# 135    6.3
# 136    6.4
# 137    6.0
# 138    6.9
# 139    6.7
# 140    6.9
# 141    5.8
# 142    6.8
# 143    6.7
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: pl, Length: 149, dtype: float64

# %%
df["sl"]
# Out:
# 0      1.4
# 1      1.3
# 2      1.5
# 3      1.4
# 4      1.7
# 5      1.4
# 6      1.5
# 7      1.4
# 8      1.5
# 9      1.5
# 10     1.6
# 11     1.4
# 12     1.1
# 13     1.2
# 14     1.5
# 15     1.3
# 16     1.4
# 17     1.7
# 18     1.5
# 19     1.7
# 20     1.5
# 21     1.0
# 22     1.7
# 23     1.9
# 24     1.6
# 25     1.6
# 26     1.5
# 27     1.4
# 28     1.6
# 29     1.6
#       ...
# 119    5.7
# 120    4.9
# 121    6.7
# 122    4.9
# 123    5.7
# 124    6.0
# 125    4.8
# 126    4.9
# 127    5.6
# 128    5.8
# 129    6.1
# 130    6.4
# 131    5.6
# 132    5.1
# 133    5.6
# 134    6.1
# 135    5.6
# 136    5.5
# 137    4.8
# 138    5.4
# 139    5.6
# 140    5.1
# 141    5.1
# 142    5.9
# 143    5.7
# 144    5.2
# 145    5.0
# 146    5.2
# 147    5.4
# 148    5.1
# Name: sl, Length: 149, dtype: float64

# %%
# df.drop(0,inplace=True)
df.drop(df.index[0],inplace=True)
df
# Out:
#       pl   pw   sl   sw      FlowerType
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 5    4.6  3.4  1.4  0.3     Iris-setosa
# 6    5.0  3.4  1.5  0.2     Iris-setosa
# 7    4.4  2.9  1.4  0.2     Iris-setosa
# 8    4.9  3.1  1.5  0.1     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 10   4.8  3.4  1.6  0.2     Iris-setosa
# 11   4.8  3.0  1.4  0.1     Iris-setosa
# 12   4.3  3.0  1.1  0.1     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# 16   5.1  3.5  1.4  0.3     Iris-setosa
# 17   5.7  3.8  1.7  0.3     Iris-setosa
# 18   5.1  3.8  1.5  0.3     Iris-setosa
# 19   5.4  3.4  1.7  0.2     Iris-setosa
# 20   5.1  3.7  1.5  0.4     Iris-setosa
# 21   4.6  3.6  1.0  0.2     Iris-setosa
# 22   5.1  3.3  1.7  0.5     Iris-setosa
# 23   4.8  3.4  1.9  0.2     Iris-setosa
# ...

# %%
a=df.sl>5
a.describe()
a.sum()
# Out:
# 42

# %%
df.loc[149]=[1,2,3,4,"amit"]

# %%
df.tail()
# Out:
#       pl   pw   sl   sw      FlowerType
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 0    1.0  2.0  3.0  4.0            amit
# 149  1.0  2.0  3.0  4.0            amit

# %%
df.drop(0,inplace=True)
df.tail()
# Out:
#       pl   pw   sl   sw      FlowerType
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 149  1.0  2.0  3.0  4.0            amit

# %%
df.mean()
# Out:
# pl    5.829730
# pw    3.043243
# sl    3.802027
# sw    1.237838
# dtype: float64

# %%
df.mode()
# Out:
#     pl   pw   sl   sw       FlowerType
# 0  5.0  3.0  1.5  0.2  Iris-versicolor
# 1  NaN  NaN  NaN  NaN   Iris-virginica

# %%
df.head()
# Out:
#     pl   pw   sl   sw   FlowerType
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df.reset_index(inplace=True)
df.drop("index",axis=1)
# Out:
#      level_0   pl   pw   sl   sw      FlowerType
# 0          0  4.6  3.1  1.5  0.2     Iris-setosa
# 1          1  5.0  3.6  1.4  0.2     Iris-setosa
# 2          2  5.4  3.9  1.7  0.4     Iris-setosa
# 3          3  4.6  3.4  1.4  0.3     Iris-setosa
# 4          4  5.0  3.4  1.5  0.2     Iris-setosa
# 5          5  4.4  2.9  1.4  0.2     Iris-setosa
# 6          6  4.9  3.1  1.5  0.1     Iris-setosa
# 7          7  5.4  3.7  1.5  0.2     Iris-setosa
# 8          8  4.8  3.4  1.6  0.2     Iris-setosa
# 9          9  4.8  3.0  1.4  0.1     Iris-setosa
# 10        10  4.3  3.0  1.1  0.1     Iris-setosa
# 11        11  5.8  4.0  1.2  0.2     Iris-setosa
# 12        12  5.7  4.4  1.5  0.4     Iris-setosa
# 13        13  5.4  3.9  1.3  0.4     Iris-setosa
# 14        14  5.1  3.5  1.4  0.3     Iris-setosa
# 15        15  5.7  3.8  1.7  0.3     Iris-setosa
# 16        16  5.1  3.8  1.5  0.3     Iris-setosa
# 17        17  5.4  3.4  1.7  0.2     Iris-setosa
# ...

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'pl', 'pw', 'sl', 'sw', 'FlowerType'], dtype='object')

# %%
df.drop("level_0",axis=1,inplace=True)

# %%
df.drop(index,axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-8cbf23ecb20d> in <module>()
# ----> 1 df.drop(index,axis=1,inplace=True)
#       2 df.head
#
# NameError: name 'index' is not defined

# %%
df.head()
# Out:
#    index   pl   pw   sl   sw   FlowerType
# 0      2  4.6  3.1  1.5  0.2  Iris-setosa
# 1      3  5.0  3.6  1.4  0.2  Iris-setosa
# 2      4  5.4  3.9  1.7  0.4  Iris-setosa
# 3      5  4.6  3.4  1.4  0.3  Iris-setosa
# 4      6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df.drop("index",axis=1,inplace=True)

# %%
df.head()
# Out:
#     pl   pw   sl   sw   FlowerType
# 0  4.6  3.1  1.5  0.2  Iris-setosa
# 1  5.0  3.6  1.4  0.2  Iris-setosa
# 2  5.4  3.9  1.7  0.4  Iris-setosa
# 3  4.6  3.4  1.4  0.3  Iris-setosa
# 4  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df.describe()
# Out:
#                pl          pw          sl          sw
# count  148.000000  148.000000  148.000000  148.000000
# mean     5.829730    3.043243    3.802027    1.237838
# std      0.914171    0.443266    1.743773    0.788558
# min      1.000000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    4.000000

# %%
df
# Out:
#       pl   pw   sl   sw      FlowerType
# 0    4.6  3.1  1.5  0.2     Iris-setosa
# 1    5.0  3.6  1.4  0.2     Iris-setosa
# 2    5.4  3.9  1.7  0.4     Iris-setosa
# 3    4.6  3.4  1.4  0.3     Iris-setosa
# 4    5.0  3.4  1.5  0.2     Iris-setosa
# 5    4.4  2.9  1.4  0.2     Iris-setosa
# 6    4.9  3.1  1.5  0.1     Iris-setosa
# 7    5.4  3.7  1.5  0.2     Iris-setosa
# 8    4.8  3.4  1.6  0.2     Iris-setosa
# 9    4.8  3.0  1.4  0.1     Iris-setosa
# 10   4.3  3.0  1.1  0.1     Iris-setosa
# 11   5.8  4.0  1.2  0.2     Iris-setosa
# 12   5.7  4.4  1.5  0.4     Iris-setosa
# 13   5.4  3.9  1.3  0.4     Iris-setosa
# 14   5.1  3.5  1.4  0.3     Iris-setosa
# 15   5.7  3.8  1.7  0.3     Iris-setosa
# 16   5.1  3.8  1.5  0.3     Iris-setosa
# 17   5.4  3.4  1.7  0.2     Iris-setosa
# 18   5.1  3.7  1.5  0.4     Iris-setosa
# 19   4.6  3.6  1.0  0.2     Iris-setosa
# 20   5.1  3.3  1.7  0.5     Iris-setosa
# 21   4.8  3.4  1.9  0.2     Iris-setosa
# ...

# %%
df.iloc[0:5,:]
# Out:
#     pl   pw   sl   sw   FlowerType
# 0  4.6  3.1  1.5  0.2  Iris-setosa
# 1  5.0  3.6  1.4  0.2  Iris-setosa
# 2  5.4  3.9  1.7  0.4  Iris-setosa
# 3  4.6  3.4  1.4  0.3  Iris-setosa
# 4  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df.loc[0]=[1,2,3,4,"amit_pratap"]

# %%
df["FlowerType"].sum
# Out:
# <bound method Series.sum of 0         amit_pratap
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 118    Iris-virginica
# 119    Iris-virginica
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# ...

# %%
df.describe()
# Out:
#                pl          pw          sl          sw
# count  148.000000  148.000000  148.000000  148.000000
# mean     5.805405    3.035811    3.812162    1.263514
# std      0.991720    0.451454    1.734637    0.815926
# min      1.000000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.375000
# 50%      5.800000    3.000000    4.400000    1.350000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    4.000000

# %%
del(df["sw"])

# %%
df.head()
# Out:
#     pl   pw   sl   FlowerType
# 0  1.0  2.0  3.0  amit_pratap
# 1  5.0  3.6  1.4  Iris-setosa
# 2  5.4  3.9  1.7  Iris-setosa
# 3  4.6  3.4  1.4  Iris-setosa
# 4  5.0  3.4  1.5  Iris-setosa

# %%
df=iris.copy()

# %%
df.columns=[1,2,3,4,"head"]

# %%
df.head()
# Out:
#      1    2    3    4         head
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.loc[1:3,2:4]=np.nan

# %%
df.head(6)
# Out:
#      1    2    3    4         head
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  NaN  NaN  Iris-setosa
# 2  4.6  3.1  NaN  NaN  Iris-setosa
# 3  5.0  3.6  NaN  NaN  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
df[3].fillna(5,inplace=True)

# %%
df.head()
# Out:
#      1    2    3    4         head
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  5.0  NaN  Iris-setosa
# 2  4.6  3.1  5.0  NaN  Iris-setosa
# 3  5.0  3.6  5.0  NaN  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df[4].fillna(df[4].mean(),inplace=True)

# %%
df.head()
# Out:
#      1    2    3         4         head
# 0  4.9  3.0  1.4  0.200000  Iris-setosa
# 1  4.7  3.2  5.0  1.226027  Iris-setosa
# 2  4.6  3.1  5.0  1.226027  Iris-setosa
# 3  5.0  3.6  5.0  1.226027  Iris-setosa
# 4  5.4  3.9  1.7  0.400000  Iris-setosa

# %%
df["Gender"]="Male"

# %%
df.head()
# Out:
#      1    2    3         4         head Gender
# 0  4.9  3.0  1.4  0.200000  Iris-setosa   Male
# 1  4.7  3.2  5.0  1.226027  Iris-setosa   Male
# 2  4.6  3.1  5.0  1.226027  Iris-setosa   Male
# 3  5.0  3.6  5.0  1.226027  Iris-setosa   Male
# 4  5.4  3.9  1.7  0.400000  Iris-setosa   Male

# %%
for i in range(0,145,2):
    df[i,5]="Female"

# %%
df.head
# Out:
# <bound method NDFrame.head of        1    2    3         4            head Gender  (0, 5)  (2, 5)  (4, 5)  \
# 0    4.9  3.0  1.4  0.200000     Iris-setosa   Male  Female  Female  Female
# 1    4.7  3.2  5.0  1.226027     Iris-setosa   Male  Female  Female  Female
# 2    4.6  3.1  5.0  1.226027     Iris-setosa   Male  Female  Female  Female
# 3    5.0  3.6  5.0  1.226027     Iris-setosa   Male  Female  Female  Female
# 4    5.4  3.9  1.7  0.400000     Iris-setosa   Male  Female  Female  Female
# 5    4.6  3.4  1.4  0.300000     Iris-setosa   Male  Female  Female  Female
# 6    5.0  3.4  1.5  0.200000     Iris-setosa   Male  Female  Female  Female
# 7    4.4  2.9  1.4  0.200000     Iris-setosa   Male  Female  Female  Female
# 8    4.9  3.1  1.5  0.100000     Iris-setosa   Male  Female  Female  Female
# 9    5.4  3.7  1.5  0.200000     Iris-setosa   Male  Female  Female  Female
# 10   4.8  3.4  1.6  0.200000     Iris-setosa   Male  Female  Female  Female
# ...

# %%
del df["Gender"]

# %%
df.head()
# Out:
#      1    2    3         4         head  (0, 5)  (2, 5)  (4, 5)  (6, 5)  \
# 0  4.9  3.0  1.4  0.200000  Iris-setosa  Female  Female  Female  Female
# 1  4.7  3.2  5.0  1.226027  Iris-setosa  Female  Female  Female  Female
# 2  4.6  3.1  5.0  1.226027  Iris-setosa  Female  Female  Female  Female
# 3  5.0  3.6  5.0  1.226027  Iris-setosa  Female  Female  Female  Female
# 4  5.4  3.9  1.7  0.400000  Iris-setosa  Female  Female  Female  Female
#
#    (8, 5)   ...    (126, 5) (128, 5) (130, 5) (132, 5) (134, 5) (136, 5)  \
# 0  Female   ...      Female   Female   Female   Female   Female   Female
# 1  Female   ...      Female   Female   Female   Female   Female   Female
# 2  Female   ...      Female   Female   Female   Female   Female   Female
# 3  Female   ...      Female   Female   Female   Female   Female   Female
# 4  Female   ...      Female   Female   Female   Female   Female   Female
#
#   (138, 5) (140, 5) (142, 5) (144, 5)
# 0   Female   Female   Female   Female
# ...

# %%
for i in range(0,145,2):
    del df[(i,5)]

# %%
df.head()
# Out:
#      1    2    3         4         head
# 0  4.9  3.0  1.4  0.200000  Iris-setosa
# 1  4.7  3.2  5.0  1.226027  Iris-setosa
# 2  4.6  3.1  5.0  1.226027  Iris-setosa
# 3  5.0  3.6  5.0  1.226027  Iris-setosa
# 4  5.4  3.9  1.7  0.400000  Iris-setosa

# %%
df["Gender"]="Male"

# %%
df.head()
# Out:
#      1    2    3         4         head Gender
# 0  4.9  3.0  1.4  0.200000  Iris-setosa   Male
# 1  4.7  3.2  5.0  1.226027  Iris-setosa   Male
# 2  4.6  3.1  5.0  1.226027  Iris-setosa   Male
# 3  5.0  3.6  5.0  1.226027  Iris-setosa   Male
# 4  5.4  3.9  1.7  0.400000  Iris-setosa   Male

# %%
for i in range(0,145,2):
    df.iloc[i,5]="Female"

# %%
df.head()
# Out:
#      1    2    3         4         head  Gender
# 0  4.9  3.0  1.4  0.200000  Iris-setosa  Female
# 1  4.7  3.2  5.0  1.226027  Iris-setosa    Male
# 2  4.6  3.1  5.0  1.226027  Iris-setosa  Female
# 3  5.0  3.6  5.0  1.226027  Iris-setosa    Male
# 4  5.4  3.9  1.7  0.400000  Iris-setosa  Female

# %%
df.describe()
# Out:
#                 1           2          3           4
# count  149.000000  149.000000  149.00000  149.000000
# mean     5.848322    3.051007    3.84698    1.226027
# std      0.828594    0.433499    1.73410    0.747433
# min      4.300000    2.000000    1.00000    0.100000
# 25%      5.100000    2.800000    1.60000    0.400000
# 50%      5.800000    3.000000    4.40000    1.300000
# 75%      6.400000    3.300000    5.10000    1.800000
# max      7.900000    4.400000    6.90000    2.500000

# %%
def f (s):
    if s=="Male":
        return 1
    else:
        return 0
    
df["sex"]=df["Gender"].apply(f)

# %%
df.head()
# Out:
#      1    2    3         4         head  Gender  sex
# 0  4.9  3.0  1.4  0.200000  Iris-setosa  Female    0
# 1  4.7  3.2  5.0  1.226027  Iris-setosa    Male    1
# 2  4.6  3.1  5.0  1.226027  Iris-setosa  Female    0
# 3  5.0  3.6  5.0  1.226027  Iris-setosa    Male    1
# 4  5.4  3.9  1.7  0.400000  Iris-setosa  Female    0

# %%
len(df)
# Out:
# 149

# %%
df.drop("Gender",axis=1,inplace=True)
df.head()
# Out:
#      1    2    3         4         head  sex
# 0  4.9  3.0  1.4  0.200000  Iris-setosa    0
# 1  4.7  3.2  5.0  1.226027  Iris-setosa    1
# 2  4.6  3.1  5.0  1.226027  Iris-setosa    0
# 3  5.0  3.6  5.0  1.226027  Iris-setosa    1
# 4  5.4  3.9  1.7  0.400000  Iris-setosa    0

# %%
#titanic DataSet

# %%
t=pd.read_csv("http://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

# %%
t.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
del t["Name"]

# %%
t.head()
# Out:
#    Survived  Pclass     Sex   Age  Siblings/Spouses Aboard  \
# 0         0       3    male  22.0                        1
# 1         1       1  female  38.0                        1
# 2         1       3  female  26.0                        0
# 3         1       1  female  35.0                        1
# 4         0       3    male  35.0                        0
#
#    Parents/Children Aboard     Fare
# 0                        0   7.2500
# 1                        0  71.2833
# 2                        0   7.9250
# 3                        0  53.1000
# 4                        0   8.0500

# %%
t.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# ...

# %%
t.sum()
# Out:
# Survived                                                                 342
# Pclass                                                                  2045
# Sex                        malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                                  26141.2
# Siblings/Spouses Aboard                                                  466
# Parents/Children Aboard                                                  340
# Fare                                                                 28654.9
# dtype: object

# %%
t.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
t.head()
# Out:
#    Survived  Pclass     Sex   Age  Siblings/Spouses Aboard  \
# 0         0       3    male  22.0                        1
# 1         1       1  female  38.0                        1
# 2         1       3  female  26.0                        0
# 3         1       1  female  35.0                        1
# 4         0       3    male  35.0                        0
#
#    Parents/Children Aboard     Fare
# 0                        0   7.2500
# 1                        0  71.2833
# 2                        0   7.9250
# 3                        0  53.1000
# 4                        0   8.0500

# %%
t['Gender']=t['Sex'].apply(f)

# %%
def f(s):
    if s=='male':
        return 1
    return 0

# %%
del t['Sex']

# %%
t.head()
# Out:
#    Survived  Pclass   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0         0       3  22.0                        1                        0
# 1         1       1  38.0                        1                        0
# 2         1       3  26.0                        0                        0
# 3         1       1  35.0                        1                        0
# 4         0       3  35.0                        0                        0
#
#       Fare  Gender
# 0   7.2500       1
# 1  71.2833       0
# 2   7.9250       0
# 3  53.1000       0
# 4   8.0500       1

# %%
t.drop("Siblings/Spouses Aboard",axis=1,inplace=True)

# %%
t.head()
# Out:
#    Survived  Pclass   Age  Parents/Children Aboard     Fare  Gender
# 0         0       3  22.0                        0   7.2500       1
# 1         1       1  38.0                        0  71.2833       0
# 2         1       3  26.0                        0   7.9250       0
# 3         1       1  35.0                        0  53.1000       0
# 4         0       3  35.0                        0   8.0500       1

# %%
t.isnull().sum()
# Out:
# Survived                   0
# Pclass                     0
# Age                        0
# Parents/Children Aboard    0
# Fare                       0
# Gender                     0
# dtype: int64

# %%
t.iloc[2:5,1:3]=np.nan

# %%
t.head(6)
# Out:
#    Survived  Pclass   Age  Parents/Children Aboard     Fare  Gender
# 0         0     3.0  22.0                        0   7.2500       1
# 1         1     1.0  38.0                        0  71.2833       0
# 2         1     NaN   NaN                        0   7.9250       0
# 3         1     NaN   NaN                        0  53.1000       0
# 4         0     NaN   NaN                        0   8.0500       1
# 5         0     3.0  27.0                        0   8.4583       1

# %%
a=t.Survived==1
t.iloc[2:5 and t[:,0]==1,2]=t["Age"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-223-f5d3e238087a> in <module>()
#       1 a=t.Survived==1
# ----> 2 t.iloc[2:5 and t[:,0]==1,2]=t["Age"].mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
# ...

# %%
t
# Out:
#      Survived  Pclass        Age  Parents/Children Aboard      Fare  Gender
# 0           0     3.0  22.000000                        0    7.2500       1
# 1           1     1.0  38.000000                        0   71.2833       0
# 2           1     NaN  29.403799                        0    7.9250       0
# 3           1     NaN  29.403799                        0   53.1000       0
# 4           0     NaN  29.403799                        0    8.0500       1
# 5           0     3.0  27.000000                        0    8.4583       1
# 6           0     1.0  54.000000                        0   51.8625       1
# 7           0     3.0   2.000000                        1   21.0750       1
# 8           1     3.0  27.000000                        2   11.1333       0
# 9           1     2.0  14.000000                        0   30.0708       0
# 10          1     3.0   4.000000                        1   16.7000       0
# ...
